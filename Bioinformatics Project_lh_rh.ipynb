# %%
# %matplotlib inline

from itertools import islice
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
concentrations = pd.read_csv('ConcentrationsData.csv', sep = ",", low_memory=False)
concentrations
# Out:
#            Ethnicity  Gender  Dominant Hand  Trial Run Subject Number   \
# 0   African American    Male            NaN          2    M3-100818-RH
# 1   African American    Male            NaN          4   M13-100818-RH
# 2   African American    Male            NaN          6   M14-100818-RH
# 3   African American  Female            NaN          8    F5-092718-RH
# 4           Hispanic  Female            NaN         10   F10-092718-RH
# 5           Hispanic    Male            NaN         12   M11-092718-RH
# 6           Hispanic    Male            NaN         14   M12-092718-RH
# 7   African American  Female            NaN         16   F11-100118-RH
# 8           Hispanic  Female            NaN         18   F12-100118-RH
# 9           Hispanic  Female            NaN         20   F13-100118-RH
# 10  African American    Male            NaN          1    M3-100818-LH
# 11  African American    Male            NaN          3   M13-100818-LH
# ...

# %%
reader = pd.read_csv('ConcentrationsData.csv', delimiter=',')
print(reader.columns[2])
#for column in reader.columns[:]:
#    print(reader[column])
#row = next(islice(reader, 5))  # skip to index rownumber, read that
#print (row)    
#for column in reader:
    #print (column)
    #for column in row:
        #print(column)
        #if(column.isdigit()):
         #   if (float(column) < 0.8):
          #      print (column)
           #     column = 0;
# Out:
# Dominant Hand

# %%
concentrations = pd.read_csv('ConcentrationsData.csv', sep = ",", low_memory=False)
concentrationsdjasbdjhsabdsa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5893a06acbd4> in <module>()
#       1 concentrations = pd.read_csv('ConcentrationsData.csv', sep = ",", low_memory=False)
# ----> 2 concentrationsdjasbdjhsabdsa
#
# NameError: name 'concentrationsdjasbdjhsabdsa' is not defined

# %%
for i in numFiles:
    file = open(os.path.join(pathName, i), "rU")
    reader = csv.reader(file, delimiter=',')
    for row in reader:
        for column in row:
            print(column)
            if column=="SPECIFIC VALUE":
                #do stuff

# %%
concentrations.columns
# Out:
# Index(['Ethnicity', 'Gender', 'Dominant Hand', 'Trial Run', 'Subject Number ',
#        '1-Chlorononane', '1-nonanol', '1-Octadecene', '2,4-Diisopropylphenol',
#        'alpha-amylcinnamaldehyde', 'alpha-hexylcinnameldehyde', 'Benzophenone',
#        'Decanal', 'Dibutyl Phthalate', 'Dodecanoic acid', 'heptadecane',
#        'Hexadecane ', 'Hexyl salicylate', 'Isopropyl Myristate',
#        'Methyl Decanoate', 'Methyl palmitate', 'Napthalene', 'Nonanal',
#        'Octadecane', 'Pentadecane', 'Pristane', 'Tetradecane',
#        'Tetradecanoic acid', 'Undecanoic Acid', 'Isopropyl Palmitate',
#        'Isoamyl Salicylate', 'Decanoic Acid', 'Octacosane'],
#       dtype='object')

# %%
dfConc=pd.DataFrame(concentrations)
dfConc
# Out:
#            Ethnicity  Gender  Dominant Hand  Trial Run Subject Number   \
# 0   African American    Male            NaN          1    M3-100818-LH
# 1   African American    Male            NaN          2    M3-100818-RH
# 2   African American    Male            NaN          3   M13-100818-LH
# 3   African American    Male            NaN          4   M13-100818-RH
# 4   African American    Male            NaN          5   M14-100818-LH
# 5   African American    Male            NaN          6   M14-100818-RH
# 6   African American  Female            NaN          7    F5-092718-LH
# 7   African American  Female            NaN          8    F5-092718-RH
# 8           Hispanic  Female            NaN          9   F10-092718-LH
# 9           Hispanic  Female            NaN         10   F10-092718-RH
# 10          Hispanic    Male            NaN         11   M11-092718-LH
# 11          Hispanic    Male            NaN         12   M11-092718-RH
# ...

# %%
dfConc.infer_objects()
# Out:
#            Ethnicity  Gender  Dominant Hand  Trial Run Subject Number   \
# 0   African American    Male            NaN          1    M3-100818-LH
# 1   African American    Male            NaN          2    M3-100818-RH
# 2   African American    Male            NaN          3   M13-100818-LH
# 3   African American    Male            NaN          4   M13-100818-RH
# 4   African American    Male            NaN          5   M14-100818-LH
# 5   African American    Male            NaN          6   M14-100818-RH
# 6   African American  Female            NaN          7    F5-092718-LH
# 7   African American  Female            NaN          8    F5-092718-RH
# 8           Hispanic  Female            NaN          9   F10-092718-LH
# 9           Hispanic  Female            NaN         10   F10-092718-RH
# 10          Hispanic    Male            NaN         11   M11-092718-LH
# 11          Hispanic    Male            NaN         12   M11-092718-RH
# ...

# %%
dfConc['Octadecane'].describe()
# Out:
# count    20.000000
# mean      3.589497
# std       8.195499
# min       0.000000
# 25%       0.535494
# 50%       0.842298
# 75%       1.465093
# max      29.102695
# Name: Octadecane, dtype: float64

# %%
dfConc.iloc[5]
# Out:
# Ethnicity                    African American
# Gender                                   Male
# Dominant Hand                             NaN
# Trial Run                                   6
# Subject Number                  M14-100818-RH
# 1-Chlorononane                              0
# 1-nonanol                                   0
# 1-Octadecene                                0
# 2,4-Diisopropylphenol                       0
# alpha-amylcinnamaldehyde                    0
# alpha-hexylcinnameldehyde                   0
# Benzophenone                                0
# Decanal                              0.683286
# Dibutyl Phthalate                           0
# Dodecanoic acid                             0
# heptadecane                          0.528593
# Hexadecane                             0.6267
# Hexyl salicylate                            0
# Isopropyl Myristate                         0
# Methyl Decanoate                     0.794635
# ...

# %%
dfLeft = pd.DataFrame()
dfRight = pd.DataFrame()
for row_index, row in dfConc.iterrows():
    #print (row_index, String(row[4])
    if "L" in str(row[4]):
        dfLeft.append(dfConc.iloc[4])
    
dfLeft
        #dfLeft.Append(row)
    
    #if("L" in dfConc.iloc[i]){
    #    dfLeft.append(dfConc[i])
    #}
    #else {
    #    dfRight = pd.DataFrame(dfConc[i])
    #}*/
#dfLeft
#dfRight
# Out:
# Empty DataFrame
# Columns: []
# Index: []
