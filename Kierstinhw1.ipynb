# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
concentrations = pd.read_csv('ConcentrationsData.csv', sep = ",", low_memory=False)
concentrations
# Out:
#            Ethnicity  Gender  Dominant Hand  Trial Run Subject Number   \
# 0   African American    Male            NaN          1    M3-100818-LH
# 1   African American    Male            NaN          2    M3-100818-RH
# 2   African American    Male            NaN          3   M13-100818-LH
# 3   African American    Male            NaN          4   M13-100818-RH
# 4   African American    Male            NaN          5   M14-100818-LH
# 5   African American    Male            NaN          6   M14-100818-RH
# 6   African American  Female            NaN          7    F5-092718-LH
# 7   African American  Female            NaN          8    F5-092718-RH
# 8           Hispanic  Female            NaN          9   F10-092718-LH
# 9           Hispanic  Female            NaN         10   F10-092718-RH
# 10          Hispanic    Male            NaN         11   M11-092718-LH
# 11          Hispanic    Male            NaN         12   M11-092718-RH
# ...

# %%
concentrations.columns # list all columns
# Out:
# Index(['Ethnicity', 'Gender', 'Dominant Hand', 'Trial Run', 'Subject Number ',
#        '1-Chlorononane', '1-nonanol', '1-Octadecene', '2,4-Diisopropylphenol',
#        'alpha-amylcinnamaldehyde', 'alpha-hexylcinnameldehyde', 'Benzophenone',
#        'Decanal', 'Dibutyl Phthalate', 'Dodecanoic acid', 'heptadecane',
#        'Hexadecane ', 'Hexyl salicylate', 'Isopropyl Myristate',
#        'Methyl Decanoate', 'Methyl palmitate', 'Napthalene', 'Nonanal',
#        'Octadecane', 'Pentadecane', 'Pristane', 'Tetradecane',
#        'Tetradecanoic acid', 'Undecanoic Acid', 'Isopropyl Palmitate',
#        'Isoamyl Salicylate', 'Decanoic Acid', 'Octacosane'],
#       dtype='object')

# %%
dfConc = pd.DataFrame(concentrations)
dfConc
# Out:
#            Ethnicity  Gender  Dominant Hand  Trial Run Subject Number   \
# 0   African American    Male            NaN          1    M3-100818-LH
# 1   African American    Male            NaN          2    M3-100818-RH
# 2   African American    Male            NaN          3   M13-100818-LH
# 3   African American    Male            NaN          4   M13-100818-RH
# 4   African American    Male            NaN          5   M14-100818-LH
# 5   African American    Male            NaN          6   M14-100818-RH
# 6   African American  Female            NaN          7    F5-092718-LH
# 7   African American  Female            NaN          8    F5-092718-RH
# 8           Hispanic  Female            NaN          9   F10-092718-LH
# 9           Hispanic  Female            NaN         10   F10-092718-RH
# 10          Hispanic    Male            NaN         11   M11-092718-LH
# 11          Hispanic    Male            NaN         12   M11-092718-RH
# ...

# %%
pivotData1999 = data1999df.pivot_table('Sampling Frequency', index=['State Code'],
                    aggfunc='count')
pivotData1999.head()
# Out:
#             Sampling Frequency
# State Code
# 01                        3184
# 02                         452
# 04                        2061
# 05                         467
# 06                        9656

# %%
data2012 = pd.read_csv('RD_501_88101_2012-0.txt', sep = "|", low_memory=False)
data2012.head()
# Out:
#    # RD  Action Code  State Code  County Code  Site ID  Parameter  POC  \
# 0  # RC  Action Code  State Code  County Code  Site ID  Parameter  POC
# 1    RD            I          01          003     0010      88101    1
# 2    RD            I          01          003     0010      88101    1
# 3    RD            I          01          003     0010      88101    1
# 4    RD            I          01          003     0010      88101    1
#
#   Sample Duration    Unit Method     ...      Qualifier - 3  Qualifier - 4  \
# 0            Unit  Method   Year     ...      Qualifier - 4  Qualifier - 5
# 1               7     105    118     ...                NaN            NaN
# 2               7     105    118     ...                NaN            NaN
# 3               7     105    118     ...                NaN            NaN
# 4               7     105    118     ...                NaN            NaN
#
#    Qualifier - 5  Qualifier - 6  Qualifier - 7  Qualifier - 8   Qualifier - 9  \
# ...

# %%
data2012 = data2012[1:] # delete the first row starting with "# RC"
data2012 = data2012[:-1] # delete last row with number of entries
data2012.head()
# Out:
#   # RD Action Code State Code County Code Site ID Parameter POC  \
# 1   RD           I         01         003    0010     88101   1
# 2   RD           I         01         003    0010     88101   1
# 3   RD           I         01         003    0010     88101   1
# 4   RD           I         01         003    0010     88101   1
# 5   RD           I         01         003    0010     88101   1
#
#   Sample Duration Unit Method     ...     Qualifier - 3 Qualifier - 4  \
# 1               7  105    118     ...               NaN           NaN
# 2               7  105    118     ...               NaN           NaN
# 3               7  105    118     ...               NaN           NaN
# 4               7  105    118     ...               NaN           NaN
# 5               7  105    118     ...               NaN           NaN
#
#   Qualifier - 5 Qualifier - 6 Qualifier - 7 Qualifier - 8 Qualifier - 9  \
# 1           NaN           NaN           NaN           NaN           NaN
# ...

# %%
data2012.columns # list all columns
# Out:
# Index(['# RD', 'Action Code', 'State Code', 'County Code', 'Site ID',
#        'Parameter', 'POC', 'Sample Duration', 'Unit', 'Method', 'Date',
#        'Start Time', 'Sample Value', 'Null Data Code', 'Sampling Frequency',
#        'Monitor Protocol (MP) ID', 'Qualifier - 1', 'Qualifier - 2',
#        'Qualifier - 3', 'Qualifier - 4', 'Qualifier - 5', 'Qualifier - 6',
#        'Qualifier - 7', 'Qualifier - 8', 'Qualifier - 9', 'Qualifier - 10',
#        'Alternate Method Detectable Limit', 'Uncertainty'],
#       dtype='object')

# %%
data2012df = pd.DataFrame(data2012, columns = ['# RD', 'Action Code', 'State Code', 'County Code', 'Site ID',
       'Parameter', 'POC', 'Sample Duration', 'Unit', 'Method', 'Date',
       'Start Time', 'Sample Value', 'Null Data Code', 'Sampling Frequency',
       'Monitor Protocol (MP) ID'])
data2012df.head()
# Out:
#   # RD Action Code State Code County Code Site ID Parameter POC  \
# 1   RD           I         01         003    0010     88101   1
# 2   RD           I         01         003    0010     88101   1
# 3   RD           I         01         003    0010     88101   1
# 4   RD           I         01         003    0010     88101   1
# 5   RD           I         01         003    0010     88101   1
#
#   Sample Duration Unit Method      Date Start Time Sample Value  \
# 1               7  105    118  20120101      00:00          6.7
# 2               7  105    118  20120104      00:00            9
# 3               7  105    118  20120107      00:00          6.5
# 4               7  105    118  20120110      00:00            7
# 5               7  105    118  20120113      00:00          5.8
#
#   Null Data Code Sampling Frequency Monitor Protocol (MP) ID
# 1            NaN                  3                      NaN
# 2            NaN                  3                      NaN
# ...

# %%
pivotData2012 = data2012df.pivot_table('Sampling Frequency', index=['State Code'],
                    aggfunc='count')
pivotData2012.head()
# Out:
#             Sampling Frequency
# State Code
# 01                        1596
# 02                         284
# 04                         792
# 05                        1452
# 06                        5395

# %%
# a) Row and colum count for the 2012 and 1999 data

# %%
data2012df.shape
# Out:
# (1304287, 16)

# %%
data1999df.shape
# Out:
# (117421, 16)

# %%
# question (c) the fraction of air quality index values that are missing

# %%
sampleVal2012 = data2012df['Sample Value']

sampleVal2012Null = sampleVal2012.isna().sum()
sampleVal2012Rows = sampleVal2012.shape

print("there are " + str(sampleVal2012Null) + "/" + str(sampleVal2012Rows) + " null values in the Sample Value fields")
#the total values in the 2012 data that are null
# Out:
# there are 73133/(1304287,) null values in the Sample Value fields

# %%
sampleVal1999 = data1999df['Sample Value']

sampleVal1999Null = sampleVal1999.isna().sum()
sampleVal1999Rows = sampleVal1999.shape

print("there are " + str(sampleVal1999Null) + "/" + str(sampleVal1999Rows) + " null values in the Sample Value fields")
#the total values in the 2012 data that are null
# Out:
# there are 13217/(117421,) null values in the Sample Value fields

# %%
# question (b) the total air quality index's missing from both files

# %%
sampleVal1999Null + sampleVal2012Null
# Out:
# 86350

# %%
# question (d) how does the average air quaity for the whole country compare for the two years?

# %%
data1999df['Sample Value'] = pd.to_numeric(data1999df['Sample Value'], errors='coerce')
data1999df
# Out:
#        # RD Action Code State Code County Code Site ID Parameter POC  \
# 1        RD           I         01         027    0001     88101   1
# 2        RD           I         01         027    0001     88101   1
# 3        RD           I         01         027    0001     88101   1
# 4        RD           I         01         027    0001     88101   1
# 5        RD           I         01         027    0001     88101   1
# 6        RD           I         01         027    0001     88101   1
# 7        RD           I         01         027    0001     88101   1
# 8        RD           I         01         027    0001     88101   1
# 9        RD           I         01         027    0001     88101   1
# 10       RD           I         01         027    0001     88101   1
# 11       RD           I         01         027    0001     88101   1
# 12       RD           I         01         027    0001     88101   1
# 13       RD           I         01         027    0001     88101   1
# ...

# %%
data1999df['Sample Value'].describe()
# Out:
# count    104204.000000
# mean         13.738101
# std           9.409935
# min           0.000000
# 25%           7.200000
# 50%          11.500000
# 75%          17.900000
# max         157.100000
# Name: Sample Value, dtype: float64

# %%
mean1999 = data1999df['Sample Value'].mean()
mean1999
# Out:
# 13.738101387662327

# %%
data2012df['Sample Value'] = pd.to_numeric(data2012df['Sample Value'], errors='coerce')
data2012df.head()
# Out:
#   # RD Action Code State Code County Code Site ID Parameter POC  \
# 1   RD           I         01         003    0010     88101   1
# 2   RD           I         01         003    0010     88101   1
# 3   RD           I         01         003    0010     88101   1
# 4   RD           I         01         003    0010     88101   1
# 5   RD           I         01         003    0010     88101   1
#
#   Sample Duration Unit Method      Date Start Time  Sample Value  \
# 1               7  105    118  20120101      00:00           6.7
# 2               7  105    118  20120104      00:00           9.0
# 3               7  105    118  20120107      00:00           6.5
# 4               7  105    118  20120110      00:00           7.0
# 5               7  105    118  20120113      00:00           5.8
#
#   Null Data Code Sampling Frequency Monitor Protocol (MP) ID
# 1            NaN                  3                      NaN
# 2            NaN                  3                      NaN
# ...

# %%
data2012df['Sample Value'].describe()
# Out:
# count    1.231154e+06
# mean     9.139924e+00
# std      8.556330e+00
# min     -1.000000e+01
# 25%      4.000000e+00
# 50%      7.633330e+00
# 75%      1.200000e+01
# max      9.089700e+02
# Name: Sample Value, dtype: float64

# %%
mean2012 = data2012df['Sample Value'].mean()
mean2012
# Out:
# 9.139924318818416

# %%
print("The average amount of fine particulate matter in the air went down from %.2f in 1999 to %.2f in 2012" % (mean1999, mean2012))
# Out:
# The average amount of fine particulate matter in the air went down from 13.74 in 1999 to 9.14 in 2012

# %%
# e) What is the standard Deviation for the two sets

# %%
data2012df['Sample Value'].std()
# Out:
# 8.556329946377055

# %%
data1999df['Sample Value'].std()
# Out:
# 9.409934889667282

# %%
# f) 
print ("Based on this brief analysis of this data, the Clean Air Act seems effective. There was significant improvement. \nThere seeems to be higher variation in the year 2012 however, based on its higher standard deviation.")
# Out:
# Based on this brief analysis of this data, the Clean Air Act seems effective. There was significant improvement.
# There seeems to be higher variation in the year 2012 however, based on its higher standard deviation.

# %%
data1999df['Sample Value'].plot.hist()

# %%
data2012df['Sample Value'].plot.hist()

# %%
# g) What is the average air quality and standard deviation for Florida

# %%
data1999florida = data1999df[data1999df['State Code']=='12'] #floridas state code
print(data1999florida.shape)
# Out:
# (4743, 16)

# %%
data1999florida.mean()
# Out:
# Sample Value    11.137139
# dtype: float64

# %%
data1999florida.std()
# Out:
# Sample Value    5.930369
# dtype: float64

# %%
data2012florida = data2012df[data2012df['State Code']=='12'] # 12 is floridas state code
print(data2012florida.shape)
# Out:
# (11945, 16)

# %%
data2012florida.mean()
# Out:
# Sample Value    8.23969
# dtype: float64

# %%
data2012florida.std()
# Out:
# Sample Value    5.072072
# dtype: float64

# %%
# What about the counties of Miami-Dade, Broward Monroe and Palm Beach?

# %%
# following questions using the FIPS codes for Florida States: Miami-Dade(086), Broward(011), Monroe(087), Palm Beach(099)

# %%
data1999Dade = data1999florida[data1999florida['County Code']=='086'] #Miami-Dades county code
data1999Dade.head()
# Out:
#       # RD Action Code State Code County Code Site ID Parameter POC  \
# 24276   RD           I         12         086    1016     88101   1
# 24277   RD           I         12         086    1016     88101   1
# 24278   RD           I         12         086    1016     88101   1
# 24279   RD           I         12         086    1016     88101   1
# 24280   RD           I         12         086    1016     88101   1
#
#       Sample Duration Unit Method      Date Start Time  Sample Value  \
# 24276               7  105    118  19990204      00:00          6.33
# 24277               7  105    118  19990205      00:00         15.54
# 24278               7  105    118  19990206      00:00         11.79
# 24279               7  105    118  19990207      00:00         13.87
# 24280               7  105    118  19990218      00:00          7.08
#
#       Null Data Code Sampling Frequency Monitor Protocol (MP) ID
# 24276            NaN                  1                      NaN
# ...

# %%
data1999Broward = data1999florida[data1999florida['County Code']=='011'] #Browards county code
data1999Broward.head()
# Out:
#       # RD Action Code State Code County Code Site ID Parameter POC  \
# 22074   RD           I         12         011    1002     88101   1
# 22075   RD           I         12         011    1002     88101   1
# 22076   RD           I         12         011    1002     88101   1
# 22077   RD           I         12         011    1002     88101   1
# 22078   RD           I         12         011    1002     88101   1
#
#       Sample Duration Unit Method      Date Start Time  Sample Value  \
# 22074               7  105    118  19990101      00:00          7.70
# 22075               7  105    118  19990102      00:00          8.12
# 22076               7  105    118  19990103      00:00           NaN
# 22077               7  105    118  19990104      00:00         10.20
# 22078               7  105    118  19990105      00:00         11.25
#
#       Null Data Code Sampling Frequency Monitor Protocol (MP) ID
# 22074            NaN                  3                      NaN
# ...

# %%
data1999Monroe = data1999florida[data1999florida['County Code']=='087'] #Monroe's county code
data1999Monroe.head()
# Out:
# Empty DataFrame
# Columns: [# RD, Action Code, State Code, County Code, Site ID, Parameter, POC, Sample Duration, Unit, Method, Date, Start Time, Sample Value, Null Data Code, Sampling Frequency, Monitor Protocol (MP) ID]
# Index: []

# %%
# there is no data for Monroe County, will only compare Dade, Broward and Palm Beach

# %%
data1999Palm = data1999florida[data1999florida['County Code']=='099'] #Palm County's county code
data1999Palm.head()
# Out:
#       # RD Action Code State Code County Code Site ID Parameter POC  \
# 25350   RD           I         12         099    0009     88101   1
# 25351   RD           I         12         099    0009     88101   1
# 25352   RD           I         12         099    0009     88101   1
# 25353   RD           I         12         099    0009     88101   1
# 25354   RD           I         12         099    0009     88101   1
#
#       Sample Duration Unit Method      Date Start Time  Sample Value  \
# 25350               7  105    118  19991204      00:00          0.58
# 25351               7  105    118  19991205      00:00          6.62
# 25352               7  105    118  19991206      00:00          7.12
# 25353               7  105    118  19991208      00:00         10.62
# 25354               7  105    118  19991209      00:00          6.16
#
#       Null Data Code Sampling Frequency Monitor Protocol (MP) ID
# 25350            NaN                  3                      NaN
# ...

# %%
data2012Dade = data2012florida[data2012florida['County Code']=='086'] #Miami-Dades county code
data2012Dade.head()
# Out:
#        # RD Action Code State Code County Code Site ID Parameter POC  \
# 333578   RD           I         12         086    0033     88101   1
# 333579   RD           I         12         086    0033     88101   1
# 333580   RD           I         12         086    0033     88101   1
# 333581   RD           I         12         086    0033     88101   1
# 333582   RD           I         12         086    0033     88101   1
#
#        Sample Duration Unit Method      Date Start Time  Sample Value  \
# 333578               7  105    118  20120101      00:00          40.0
# 333579               7  105    118  20120104      00:00           6.5
# 333580               7  105    118  20120107      00:00           9.1
# 333581               7  105    118  20120110      00:00           7.0
# 333582               7  105    118  20120113      00:00          10.0
#
#        Null Data Code Sampling Frequency Monitor Protocol (MP) ID
# ...

# %%
data2012Broward = data2012florida[data2012florida['County Code']=='011'] #Browards county code
data2012Broward.head()
# Out:
#        # RD Action Code State Code County Code Site ID Parameter POC  \
# 332001   RD           I         12         011    1002     88101   1
# 332002   RD           I         12         011    1002     88101   1
# 332003   RD           I         12         011    1002     88101   1
# 332004   RD           I         12         011    1002     88101   1
# 332005   RD           I         12         011    1002     88101   1
#
#        Sample Duration Unit Method      Date Start Time  Sample Value  \
# 332001               7  105    118  20120101      00:00          15.5
# 332002               7  105    118  20120102      00:00           6.8
# 332003               7  105    118  20120103      00:00           4.0
# 332004               7  105    118  20120104      00:00           5.3
# 332005               7  105    118  20120105      00:00          10.0
#
#        Null Data Code Sampling Frequency Monitor Protocol (MP) ID
# ...

# %%
data2012Palm = data2012florida[data2012florida['County Code']=='099'] #Palm County's county code
data2012Palm.head()
# Out:
#        # RD Action Code State Code County Code Site ID Parameter POC  \
# 334232   RD           I         12         099    0008     88101   3
# 334233   RD           I         12         099    0008     88101   3
# 334234   RD           I         12         099    0008     88101   3
# 334235   RD           I         12         099    0008     88101   3
# 334236   RD           I         12         099    0008     88101   3
#
#        Sample Duration Unit Method      Date Start Time  Sample Value  \
# 334232               1  105    170  20120101      00:00          14.0
# 334233               1  105    170  20120101      01:00          15.0
# 334234               1  105    170  20120101      02:00          12.0
# 334235               1  105    170  20120101      03:00          12.0
# 334236               1  105    170  20120101      04:00          12.0
#
#        Null Data Code Sampling Frequency Monitor Protocol (MP) ID
# ...

# %%
mean1999Dade = data1999Dade.mean()
std1999Dade = data1999Dade.std()
mean2012Dade = data2012Dade.mean()
std2012Dade = data2012Dade.std()

# %%
print("The average amount of fine particulate matter in the air went from %.2f in 1999 to %.2f in 2012" % (mean1999Dade, mean2012Dade))
print("The standard deviation went from %.2f in 1999 to %.2f in 2012" % (std1999Dade, std2012Dade))
# Out:
# The average amount of fine particulate matter in the air went from 10.92 in 1999 to 6.93 in 2012
# The standard deviation went from 5.43 in 1999 to 3.67 in 2012

# %%
mean1999Broward = data1999Broward.mean()
std1999Broward = data1999Broward.std()
mean2012Broward = data2012Broward.mean()
std2012Broward = data2012Broward.std()

# %%
print("The average amount of fine particulate matter in the air went from %.2f in 1999 to %.2f in 2012" % (mean1999Broward, mean2012Broward))
print("The standard deviation went from %.2f in 1999 to %.2f in 2012" % (std1999Broward, std2012Broward))
# Out:
# The average amount of fine particulate matter in the air went from 8.76 in 1999 to 6.95 in 2012
# The standard deviation went from 6.46 in 1999 to 3.19 in 2012

# %%
mean1999Palm = data1999Palm.mean()
std1999Palm = data1999Palm.std()
mean2012Palm = data2012Palm.mean()
std2012Palm = data2012Palm.std()

# %%
print("The average amount of fine particulate matter in the air went from %.2f in 1999 to %.2f in 2012" % (mean1999Palm, mean2012Palm))
print("The standard deviation went from %.2f in 1999 to %.2f in 2012" % (std1999Palm, std2012Palm))
# Out:
# The average amount of fine particulate matter in the air went from 9.31 in 1999 to 8.58 in 2012
# The standard deviation went from 4.47 in 1999 to 5.29 in 2012

# %%
# i) which states had max values, min values, best and worst increase?

# %%
data1999Dade['Sample Value'].max()
# Out:
# 56.95

# %%
data2012Dade['Sample Value'].max()
# Out:
# 49.6

# %%
data1999Broward['Sample Value'].max()
# Out:
# 107.9

# %%
data2012Broward['Sample Value'].max()
# Out:
# 32.8

# %%
data1999Palm['Sample Value'].max()
# Out:
# 26.58

# %%
data2012Palm['Sample Value'].max()
# Out:
# 82.0

# %%
#Broward had the worstpollution in 1999

# %%
# j) What kind of visualizations would you use to perform these analyses?

# %%
#data1999Dade['Sample Values'.value_counts().sort_index().plot.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-401207976126> in <module>()
# ----> 1 data1999Dade.value_counts().sort_index().plot.bar()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
#data1999Dade['Sample Values'].value_counts().sort_index().plot.line()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sample Values'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-b876229c6192> in <module>()
# ...
